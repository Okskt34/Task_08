# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = 'C:/Users/ASUS/OneDrive/Рабочий стол/train(1).csv'
df = pd.read_csv('C:/Users/ASUS/OneDrive/Рабочий стол/train(1).csv')

df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['Age'], bins=20, edgecolor='black')  # Кількість бінів (палиць) можна змінити за потребою
plt.xlabel('Вік')
plt.ylabel('Кількість')
plt.title('Діаграма розподілу віку')
plt.tight_layout()
plt.show()

# %%
mean_sp = df['Age'].mean()

# %%
df['Age'].fillna(mean_sp, inplace=True)

# %%
print(df)
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age
# 0                              Braund, Mr. Owen Harris    male  22.000000  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...
